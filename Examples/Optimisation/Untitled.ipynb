# %%
import pandas as pd

# %%
df = pd.read_csv('temp.csv')
df
# Out:
#      Polarization  Index      Diameter        Values
# 0        Parallel    1.3  1.000000e-07  1.655713e-09
# 1        Parallel    1.3  2.000000e-07  1.194375e-07
# 2        Parallel    1.3  3.000000e-07  1.406060e-06
# 3        Parallel    1.3  4.000000e-07  7.245916e-06
# 4        Parallel    1.3  5.000000e-07  2.364764e-05
# ..            ...    ...           ...           ...
# 75  Perpendicular    2.0  6.000000e-07  4.965770e+00
# 76  Perpendicular    2.0  7.000000e-07  1.505946e+01
# 77  Perpendicular    2.0  8.000000e-07  1.463001e+01
# 78  Perpendicular    2.0  9.000000e-07  1.158629e+01
# 79  Perpendicular    2.0  1.000000e-06  2.356254e+01
#
# [80 rows x 4 columns]

# %%
df.groupby(['Polarization','Diameter']).std()
# Out:
#                                Index        Values
# Polarization  Diameter
# Parallel      1.000000e-07  0.301241  6.493295e-09
#               2.000000e-07  0.301241  5.983051e-07
#               3.000000e-07  0.301241  2.908421e-06
#               4.000000e-07  0.301241  6.935654e-06
#               5.000000e-07  0.301241  1.029686e-05
#               6.000000e-07  0.301241  2.039046e-05
#               7.000000e-07  0.301241  4.012348e-05
#               8.000000e-07  0.301241  5.964593e-05
#               9.000000e-07  0.301241  1.007115e-04
#               1.000000e-06  0.301241  1.024456e-04
# Perpendicular 1.000000e-07  0.301241  1.101985e-03
#               2.000000e-07  0.301241  1.038923e-01
#               3.000000e-07  0.301241  5.107508e-01
#               4.000000e-07  0.301241  1.250402e+00
#               5.000000e-07  0.301241  1.553763e+00
#               6.000000e-07  0.301241  3.653785e+00
#               7.000000e-07  0.301241  6.464528e+00
# ...

# %%
df.assign(STD=df.groupby(['Polarization','Diameter']).Values.transform('mean'))
# Out:
#      Polarization  Index      Diameter        Values           STD
# 0        Parallel    1.3  1.000000e-07  1.655713e-09  8.395563e-09
# 1        Parallel    1.3  2.000000e-07  1.194375e-07  7.604226e-07
# 2        Parallel    1.3  3.000000e-07  1.406060e-06  4.904660e-06
# 3        Parallel    1.3  4.000000e-07  7.245916e-06  1.284722e-05
# 4        Parallel    1.3  5.000000e-07  2.364764e-05  2.449854e-05
# ..            ...    ...           ...           ...           ...
# 75  Perpendicular    2.0  6.000000e-07  4.965770e+00  7.056946e+00
# 76  Perpendicular    2.0  7.000000e-07  1.505946e+01  1.247557e+01
# 77  Perpendicular    2.0  8.000000e-07  1.463001e+01  1.735229e+01
# 78  Perpendicular    2.0  9.000000e-07  1.158629e+01  2.338190e+01
# 79  Perpendicular    2.0  1.000000e-06  2.356254e+01  3.200552e+01
#
# [80 rows x 5 columns]
