# %%
from PyMieSim.Physics import Source
from PyMieSim.Detector import LPmode, Photodiode
from PyMieSim.Scattering import Scatterer
# Out:
# [S1S2] C++ module loaded
# [GetFields] Cython module loaded

# %%
# Out:
# array([1.6])

# %%
import miepy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-bfd9c490b76a> in <module>
# ----> 1 import miepy
#
# ModuleNotFoundError: No module named 'miepy'

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
import numpy as np

axisFont = {'fontname':'serif', 'size':'14', 'weight': 'medium'}


fig = plt.figure(figsize=(10,4))
ax=fig.add_subplot(111)

data0 = np.mean( Array.squeeze(), axis=0)[0]
std0 = np.std( Array.squeeze(), axis=0)[0]
ax.plot(DiameterList*1e6, data0, label=r'$LP_{01}$', linewidth=2)
ax.fill_between(DiameterList*1e6, data0 - std0, data0 + std0, label=r"$\sigma( \widetilde{\eta}_{\,0,1})$", color='C0', alpha=0.3)

data1 = np.mean( Array.squeeze(), axis=0)[1]
std1 = np.std( Array.squeeze(), axis=0)[1]
ax.plot(DiameterList*1e6, data1, linewidth=2, label=r'$LP_{11+}$')
ax.fill_between(DiameterList*1e6, data1 - std1, data1 + std1, label=r"$\sigma( \widetilde{\eta}_{\,1,1})$", color='C1', alpha=0.3)

ax.grid()
ax.legend(bbox_to_anchor=[0.356,0.95,0.2,0.2], ncol=4)
ax.set_ylabel('Mode coupling [a.u.]', **axisFont)
ax.set_xlim([0,20])
ax2 = ax.twinx()
h = ax2.set_ylabel(r'Coupling ratio', labelpad=25,  **axisFont)
h.set_rotation(-90)
ax2.plot(DiameterList*1e6, data1/data0,'k', linewidth=2, label=r'$\Gamma_{11+}$')
ax2.legend(bbox_to_anchor=[0.81,0.95,0.2,0.2], ncol=1)
ax.set_xlabel(u'Scatterer size [\u03bcm]',**axisFont)
plt.savefig('couplingRatio.svg', format='svg')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
import numpy as np

axisFont = {'fontname':'serif', 'size':'14'}


fig = plt.figure(figsize=(10*2,4*2))
ax=fig.add_subplot(111)

#data0 = np.mean( Array.squeeze(), axis=0)[0]
#std0 = np.std( Array.squeeze(), axis=0)[0]
#ax.plot(DiameterList*1e6, data0, label=r'$LP_{01}$', linewidth=2)
#ax.fill_between(DiameterList*1e6, data0 - std0, data0 + std0, label=r"$\sigma( \widetilde{\eta}_{\,0,1})$", color='C0', alpha=0.3)

#data1 = np.mean( Array.squeeze(), axis=0)[1]
#std1 = np.std( Array.squeeze(), axis=0)[1]
#ax.plot(DiameterList*1e6, data1, linewidth=2, label=r'$LP_{11+}$')
#ax.fill_between(DiameterList*1e6, data1 - std1, data1 + std1, label=r"$\sigma( \widetilde{\eta}_{\,1,1})$", color='C1', alpha=0.3)

ax.grid()
ax.legend(bbox_to_anchor=[0.46,0.95,0.2,0.2], ncol=4)
ax.set_ylabel('Mode coupling [a.u.]')
ax.set_xlim([0,10])
ax2 = ax.twinx()
h = ax2.set_ylabel(r'Coupling ratio', labelpad=25,  fontname='fantasy', fontsize=25)
h.set_rotation(-90)
#ax2.plot(DiameterList*1e6, data1/data0,'k', linewidth=2, label=r'$\Gamma_{11+}$')
ax2.legend(bbox_to_anchor=[0.81,0.95,0.2,0.2], ncol=1)
ax.set_xlabel(u'Scatterer size [\u03bcm]')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Text(0.5, 0, 'Scatterer size [μm]')

# %%
# %matplotlib notebook
"""
_________________________________________________________
Optimization of RI dependence minimizing STD of detector response.
_________________________________________________________
"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PyMieCoupling.classes.Detector import LPmode, Photodiode
from PyMieCoupling.utils import Source
from PyMieCoupling.classes.Scattering import ScattererSet, SampleSet, Sample
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["font.family"] = "serif"
plt.rcParams['font.serif'] = ['Times New Roman']

LightSource = Source(Wavelength   = 930e-9,
                     Polarization = 0)

NA = 0.1

Detector0 = LPmode(NA                = NA,
                   Source            = LightSource,
                   Sampling          = 501,
                   GammaOffset       = 0,
                   PhiOffset         = 0,
                   Mode              = (0,1))


Detector1 = LPmode(NA                = NA,
                   Source            = LightSource,
                   Sampling          = 501,
                   GammaOffset       = 0,
                   PhiOffset         = 0,
                   Orientation       = 'h',
                   Mode              = (1,2))

base = 4.05
delta = 1.52
LcList = np.linspace(base-delta, base+delta, 300)*1e-6; 
LcList = np.linspace(0.1, 6, 300)*1e-6; 

gList = np.linspace(0.91,1,1)
D = 2.36

Set0 = SampleSet(gList        = gList,
                LcList        = LcList,
                D             = D,
                Nc            = 1e-20,
                Detector      = Detector0,
                Source        = LightSource,
                Mode          = 'Mean'
                )

Set1 = SampleSet(gList        = gList,
                LcList        = LcList,
                D             = D,
                Nc            = 1e-20,
                Detector      = Detector1,
                Source        = LightSource,
                Mode          = 'Mean'
                )

arrLP01 = Set0.GetCouplingArray()

arrLP11 = Set1.GetCouplingArray()

Samp = Sample(g           = 0.9,
              lc          = 0.6e-6,
              D           = D,
              Nc          = 1e-19,
              Source      = LightSource)

#Samp.Plot()
arrLP11 *= 0.3
fig = plt.figure(figsize=(12,4))
ax = fig.add_subplot(111)
ax.plot(LcList*1e6, arrLP01.T, label=r'$\bf{ \widetilde{\eta}_{\,0,1} }$')
ax.plot(LcList*1e6, arrLP11.T, 'C1--' , label=r'$\bf{ \widetilde{\eta}_{\,1,1} }$')

ax2 = ax.twinx()
ax.legend(loc=0, fontsize=11)
ax.grid()
ax.set_xlabel(r'Correlation lenght ($\bf{l_c}$) [$\bf{\mu}$m]')
ax.set_ylabel('Mean coupling [u.a.]')
#ax.set_title(r'Liver sample')

ax2.plot(LcList*1e6, arrLP11.T/arrLP01.T, 'k' , label=r'$\frac{\widetilde{\eta}_{\,1,1}}{\widetilde{\eta}_{\,0,1}}$')
ax2.set_ylim([0., 1.])
ax2.legend(loc=4, fontsize=13)

plt.show()
#plt.savefig('liver.png', dpi=500)
# Out:
# /home/martth/Desktop/git_project/gitlab/miecoupling/PyMieCoupling/utils.py:42: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if input == 'None':
# <img src="data:image/png;base64,..." width="1200">

# %%
# %matplotlib notebook
from PyMieCoupling.classes.Detector import Photodiode, LPmode
E = LPmode(NA                = 0.1,
           Sampling          = 401,
           GammaOffset       = 0,
           PhiOffset         = 20,
           Mode              = (0,1),
           CouplingMode      = 'Centered')

E.NA = 0.4


E.Mesh.Plot()
# Out:
# YOO
# <img src="data:image/png;base64,..." width="640">

# %%
D = LPmode(NA                = 0.2,
           Sampling          = 401,
           GammaOffset       = 0,
           PhiOffset         = 0,
           Mode              = (0,1),
           CouplingMode      = 'Centered')


D.Mesh.Plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a = (Photodiode0,)

# %%
list(a)

# %%
"""
_________________________________________________________
Optimization of RI dependence minimizing STD of detector response.
_________________________________________________________
"""

import numpy as np
from scipy.optimize import minimize
from PyMieCoupling.classes.Detector import Photodiode, LPmode
from PyMieCoupling.utils import Source
from PyMieCoupling.classes.Optimizer import Simulator
from PyMieCoupling.classes.Sets import ExperimentalSet, ScattererSet

LightSource = Source(Wavelength = 450e-9,
                     Polarization = 0,
                     Power = 1,
                     Radius = 1)



Photodiode0 = LPmode(NA                = 0.01,
                   Sampling          = 401,
                   GammaOffset       = 0,
                   PhiOffset         = 0,
                   Mode              = (0,1),
                   CouplingMode      = 'Centered')


ScatSet = ScattererSet(DiameterList  = np.linspace(100e-9, 3500e-9, 100),
                       RIList        = np.linspace(1.5, 1.5, 1).round(1),
                       Source        = LightSource)

Set = ExperimentalSet(ScattererSet  = ScatSet,
                      Detectors     = Photodiode0)


def EvalFunc(x):

    Set.Detectors['Detector 0'].NA = x[0]

    return Set.Coupling.Cost('Max') # can be: RI_STD  -  RI_RSD  -  Monotonic  -  Mean  -  Max  -  Min


Minimizer = Simulator(EvalFunc, ParameterName= ['NA'])

Result = minimize(fun      = Minimizer.simulate,
                  x0       = [0.2],
                  method   = 'COBYLA',
                  callback = Minimizer.callback,
                  tol      = 1e-5,
                  options  = {'maxiter': 100, 'rhobeg':0.1})

print(Result)

Set.DataFrame.Plot('Coupling') # can be Couplimg  -  STD








# -
# Out:
# C++ module loaded
# /home/martth/Desktop/git_project/gitlab/miecoupling/PyMieCoupling/utils.py:47: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if input == 'None':
# /home/martth/.local/lib/python3.8/site-packages/scipy/optimize/_minimize.py:543: RuntimeWarning: Method COBYLA does not support callback.
#   warn('Method %s does not support callback.' % method, RuntimeWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-ccb5da3b62a4> in <module>
#      44 Minimizer = Simulator(EvalFunc, ParameterName= ['NA'])
#      45
# ---> 46 Result = minimize(fun      = Minimizer.simulate,
#      47                   x0       = [0.2],
#      48                   method   = 'COBYLA',
#
# ...

# %%
# %matplotlib notebook
"""
_________________________________________________________
Optimization of RI dependence minimizing STD of detector response.
_________________________________________________________
"""

import numpy as np
from PyMieCoupling.classes.Detector import LPmode, Photodiode
from PyMieCoupling.utils import Source
from PyMieCoupling.classes.Sets import ScattererSet, ExperimentalSet

LightSource = Source(Wavelength = 450e-9,
                     Polarization = 0,
                     Power = 1,
                     Radius = 1)

Detector0 = Photodiode(NA                = 0.1,
                       Sampling          = 801,
                       GammaOffset       = 0,
                       PhiOffset         = 0,
                       CouplingMode      = 'Centered')


Detector2 = Photodiode(NA                = 0.1,
                       Sampling          = 501,
                       GammaOffset       = 0,
                       PhiOffset         = 0,
                       CouplingMode      = 'Centered')

Detector1 = LPmode(NA                = 0.01,
                   Sampling          = 401,
                   GammaOffset       = 0,
                   PhiOffset         = 0,
                   Mode              = (0,1),
                   CouplingMode      = 'Centered')


Set = ScattererSet(DiameterList  = np.linspace(1e-9, 10e-9, 10),
                   RIList        = np.linspace(1.4, 1.4, 1).round(1),
                   Source        = LightSource)

Experiment = ExperimentalSet(ScattererSet = Set, Detectors = [Detector0, Detector2])


from PyMieCoupling.classes.Scattering import Scatterer

Scat = Scatterer(Index=1.4, Source = LightSource, Diameter=10000e-9)

Footprint = Detector0.Footprint(Scatterer=Scat)
#Array = Experiment.Coupling
DataFrame = Experiment.DataFrame


DataFrame.Plot()
# Out:
# C++ module loaded
# /home/martth/Desktop/git_project/gitlab/miecoupling/PyMieCoupling/utils.py:47: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if input == 'None':

# %%
# Out:
# /home/martth/Desktop/git_project/gitlab/miecoupling/PyMieCoupling/utils.py:49: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if input == 'None':
# <img src="data:image/png;base64,..." width="800">

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
import numpy as np
X, Y = np.meshgrid(DiameterList*1e6, RIList) 


ax.plot_surface(X, 
                Y, 
                Experiment.Coupling[0], 
                alpha=0.8,
                cmap='hot',
                linewidth=0)

ax.set_ylabel('Refractive index')
ax.set_xlabel(r'Scatterer diameter [$\mu$m]')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'Scatterer diameter [$\\mu$m]')

# %%
# %matplotlib notebook
from scipy.interpolate import SmoothSphereBivariateSpline, LSQSphereBivariateSpline, griddata
import matplotlib.pyplot as plt




import numpy as np
from PyMieCoupling.classes.Detector import LPmode, Photodiode
from PyMieCoupling.utils import Source
from PyMieCoupling.classes.Sets import ScattererSet, ExperimentalSet

LightSource = Source(Wavelength = 450e-9,
                     Polarization = 0,
                     Power = 1,
                     Radius = 1)

Detector0 = LPmode(NA                = 0.6,
                   Sampling          = 801,
                   GammaOffset       = 0,
                   PhiOffset         = 15,
                   Mode              = (0,1,'v'),
                   CouplingMode      = 'Centered')
# Out:
# /home/martth/Desktop/git_project/gitlab/miecoupling/PyMieCoupling/utils.py:49: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if input == 'None':

# %%
import numpy as np
import matplotlib.pyplot as plt
from PyMieCoupling.classes.Detector import LPmode, Photodiode
from PyMieCoupling.Physics import Source
from PyMieCoupling.classes.Sets import ScattererSet, ExperimentalSet
from PyMieCoupling.classes.Scattering import Scatterer
from mayavi.mlab import *
from ai import cs
from mayavi import mlab


LightSource = Source(Wavelength = 450e-9,
                     Polarization = 0,
                     Power = 1,
                     Radius = 1)

Detector0 = Photodiode(NA                = 0.3,
                       Sampling          = 801,
                       GammaOffset       = 0,
                       PhiOffset         = 0,
                       CouplingMode      = 'Centered')

Detector1 = LPmode(NA                = 0.1,
                   Sampling          = 401,
                   GammaOffset       = 0,
                   PhiOffset         = 0,
                   Mode              = (0,1),
                   CouplingMode      = 'Centered')

Scat = Scatterer(Index=1.4, Source = LightSource, Diameter=10e-9)


Detector0.Mesh.Omega.Radian/ Detector0.Mesh.dOmega.Radian

Detector1.Coupling(Scat)
#mesh(x,y,z)
# Out:
# [S1S2] C++ module loaded
# [GetFields] C++ module loaded
# [S1S2] C++ module loaded
# [Efficiencies] C++ module loaded
# 1
# 2.5375166133322003e-14

# %%
Python: 2.5375166133322e-14

# %%
(1.6366926297716833e-10, 1.594113288998491e-10)

# %%
__file__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-358d5687b810> in <module>
# ----> 1 __file__
#
# NameError: name '__file__' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from PyMieCoupling.classes.Detector import LPmode, Photodiode
from PyMieCoupling.utils import Source
from PyMieCoupling.classes.Sets import ScattererSet, ExperimentalSet

LightSource = Source(Wavelength = 450e-9,
                     Polarization = 0,
                     Power = 1,
                     Radius = 1)

Detector1 = LPmode(NA                = 0.4,
                   Sampling          = 801,
                   GammaOffset       = 0,
                   PhiOffset         = 0,
                   Mode              = (0,1),
                   CouplingMode      = 'Centered')

Detector1.Plot()
# Out:
# /home/martth/Desktop/git_project/gitlab/miecoupling/PyMieCoupling/utils.py:49: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if input == 'None':

# %%
from Cython.Distutils import build_ext


a = build_ext
dir(a)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_build_extensions_parallel',
#  '_build_extensions_serial',
#  '_ensure_stringlike',
#  '_ensure_tested_string',
#  '_filter_build_errors',
#  'announce',
#  'boolean_options',
#  'build_extension',
#  'build_extensions',
#  'check_extensions_list',
#  'copy_file',
#  'copy_tree',
#  'cython_sources',
#  'debug_print',
#  'description',
#  'dump_options',
#  'ensure_dirname',
#  'ensure_filename',
#  'ensure_finalized',
#  'ensure_string',
#  'ensure_string_list',
#  'execute',
#  'finalize_options',
#  'find_swig',
#  'get_command_name',
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from PyMieSim.Source import PlaneWave
from PyMieSim.Scatterer import Sphere





WAVELENGTH=450e-9
INDEX = 1.4
DIAMETER=400e-9
SIZEPARAM = 2 * pi / WAVELENGTH * DIAMETER/2
Source = PlaneWave(Wavelength = WAVELENGTH, Polarization = 0)

Scat = Sphere(Diameter    = DIAMETER,
              Source      = Source,
              Index       = INDEX)



spf = SPF(Scat, Source, 10, phi, theta)



def Plot3d(R, Phi, Theta):
    fig, axes = plt.subplots(nrows      = 1,
                             ncols      = 1,
                             subplot_kw = {'projection':'3d'})
    
    
    X,Y,Z = cs.sp2cart(R, Phi, Theta)
    
    axes.plot_surface(X,Y,Z)

    Max = np.max(R)

    axes.set_xlim([-Max,Max])
    axes.set_ylim([-Max,Max])
    axes.set_zlim([-Max,Max])
    
    
def PlotPolar(rho, angle):
    fig, axes = plt.subplots(nrows      = 1,
                             ncols      = 1,
                             subplot_kw = {'projection':'polar'})
    
    axes.plot(angle, rho)

# %%
"""
theta = np.linspace(0, 2*pi,200)
PHI,THETA = np.meshgrid(phi, theta)
E0 = np.outer(s1, exp(1j*theta))
E1 = np.outer(s2, exp(1j*theta+pi))
E = np.abs(E0)**2 + np.abs(E1)**2



temp = E#np.outer(s1, np.abs(cos(theta)))

X,Y,Z = cs.sp2cart(np.abs(temp).T, PHI, THETA)



fig, axes = plt.subplots(nrows      = 1,
                         ncols      = 1,
                         subplot_kw = {'projection':'3d'})
axes.plot_surface(X,Y,Z)

Max = np.max(np.abs(temp))

axes.set_xlim([-Max,Max])
axes.set_ylim([-Max,Max])
axes.set_zlim([-Max,Max])
"""
# Out:
# "\ntheta = np.linspace(0, 2*pi,200)\nPHI,THETA = np.meshgrid(phi, theta)\nE0 = np.outer(s1, exp(1j*theta))\nE1 = np.outer(s2, exp(1j*theta+pi))\nE = np.abs(E0)**2 + np.abs(E1)**2\n\n\n\ntemp = E#np.outer(s1, np.abs(cos(theta)))\n\nX,Y,Z = cs.sp2cart(np.abs(temp).T, PHI, THETA)\n\n\n\nfig, axes = plt.subplots(nrows      = 1,\n                         ncols      = 1,\n                         subplot_kw = {'projection':'3d'})\naxes.plot_surface(X,Y,Z)\n\nMax = np.max(np.abs(temp))\n\naxes.set_xlim([-Max,Max])\naxes.set_ylim([-Max,Max])\naxes.set_zlim([-Max,Max])\n"
